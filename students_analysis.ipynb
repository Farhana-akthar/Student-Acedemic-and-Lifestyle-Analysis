# %%
print("Hello, Farhana! Welcome to your project.")
# Out:
# Hello, Farhana! Welcome to your project.

# %%
# Import libraries
import pandas as pd   # For data handling
import matplotlib.pyplot as plt  # For graphs
import seaborn as sns  # For nicer graphs

# Optional: make graphs appear inside notebook
# %matplotlib inline

# %%
# Load your CSV
data = pd.read_csv("student_data.csv")

# Show first 5 rows to check it
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load your CSV
# ----> 2 data = pd.read_csv("student_data.csv")
#       4 # Show first 5 rows to check it
#       5 data.head()
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ADMIN\\OneDrive\\Desktop\\students_academic_and_lifestyle_analysis'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'eda_project.ipynb',
#  'students.csv',
#  'students_analysis.ipynb']

# %%
import pandas as pd

# Load the CSV using the correct filename
data = pd.read_csv("students.csv")

# Show the first 5 rows
data.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       3 # Load the CSV using the correct filename
# ----> 4 data = pd.read_csv("students.csv")
#       6 # Show the first 5 rows
#       7 data.head()
#
# ...

# %%
import pandas as pd

data = pd.read_csv("students.csv")
data.head()
# Out:
# Exception ignored in: 'zmq.backend.cython._zmq.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/_zmq.py", line 179, in zmq.backend.cython._zmq._check_rc
#     PyErr_CheckSignals()
# ^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
# ----> 3 data = pd.read_csv("students.csv")
#       4 data.head()
#
# ...

# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv("students.csv")

# Show the first 5 rows
data.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 import pandas as pd
#       3 # Load the CSV file
# ----> 4 data = pd.read_csv("students.csv")
#       6 # Show the first 5 rows
#       7 data.head()
#
# ...

# %%
import pandas as pd

data = pd.read_csv("students.csv", encoding='utf-8')
data.head()
# Out:
#   Student_ID  Age  Gender  Study_Hours  Sleep_Hours  Attendance  GPA  \
# 0      S1001   18    Male            5            7          85  3.2
# 1      S1002   19  Female            6            8          92  3.8
# 2      S1003   20    Male            3            6          70  2.5
# 3      S1004   21  Female            4            7          80  3.0
# 4      S1005   18    Male            7            8          95  3.9
#
#   Extracurricular  Internet_Usage  Social_Media_Hours
# 0             Yes               3                   2
# 1              No               2                   1
# 2             Yes               5                   4
# 3              No               4                   3
# 4             Yes               3                   1

# %%
# Show first 5 rows of your data
data.head()
# Out:
#   Student_ID  Age  Gender  Study_Hours  Sleep_Hours  Attendance  GPA  \
# 0      S1001   18    Male            5            7          85  3.2
# 1      S1002   19  Female            6            8          92  3.8
# 2      S1003   20    Male            3            6          70  2.5
# 3      S1004   21  Female            4            7          80  3.0
# 4      S1005   18    Male            7            8          95  3.9
#
#   Extracurricular  Internet_Usage  Social_Media_Hours
# 0             Yes               3                   2
# 1              No               2                   1
# 2             Yes               5                   4
# 3              No               4                   3
# 4             Yes               3                   1

# %%
# Check data info
data.info()

# Check if any missing values
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          10 non-null     object
#  1   Age                 10 non-null     int64
#  2   Gender              10 non-null     object
#  3   Study_Hours         10 non-null     int64
#  4   Sleep_Hours         10 non-null     int64
#  5   Attendance          10 non-null     int64
#  6   GPA                 10 non-null     float64
#  7   Extracurricular     10 non-null     object
#  8   Internet_Usage      10 non-null     int64
#  9   Social_Media_Hours  10 non-null     int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 932.0+ bytes
# Student_ID            0
# Age                   0
# Gender                0
# Study_Hours           0
# Sleep_Hours           0
# Attendance            0
# GPA                   0
# Extracurricular       0
# ...

# %%
data.describe()
# Out:
#              Age  Study_Hours  Sleep_Hours  Attendance        GPA  \
# count  10.000000    10.000000    10.000000   10.000000  10.000000
# mean   19.300000     4.500000     7.000000   81.200000   3.130000
# std     1.159502     1.581139     0.816497   10.315038   0.569698
# min    18.000000     2.000000     6.000000   65.000000   2.200000
# 25%    18.250000     3.250000     6.250000   72.750000   2.750000
# 50%    19.000000     4.500000     7.000000   82.500000   3.100000
# 75%    20.000000     5.750000     7.750000   89.500000   3.575000
# max    21.000000     7.000000     8.000000   95.000000   3.900000
#
#        Internet_Usage  Social_Media_Hours
# count       10.000000           10.000000
# mean         3.700000            2.600000
# std          1.337494            1.429841
# min          2.000000            1.000000
# 25%          3.000000            1.250000
# 50%          3.500000            2.500000
# 75%          4.750000            3.750000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data['GPA'], bins=5, kde=True)
plt.title("Distribution of GPA")
plt.show()

# %%
sns.scatterplot(x='Study_Hours', y='GPA', data=data)
plt.title("Study Hours vs GPA")
plt.show()

# %%
sns.scatterplot(x='Attendance', y='GPA', data=data)
plt.title("Attendance vs GPA")
plt.show()
